# %%
#V0.1

from my_plot import Hist, sns_Hist, sns_kde
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.style
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("train.csv")

# %% [markdown]
# # ヒストグラム（全体を見るとき)
#
# ```py
# Hist(data=<DF>,
#      column_name=<DFのcolumn>,
#      bins=<bins>,
#      figsize=(<横大きさ,縦大きさ>),
#      step=<区切り>)
# ```

# %%
Hist(df, column_name="bmi", figsize=(10,10), step=2)

# %% [markdown]
# # ヒストグラム ( snsバージョン )
#
# ```py
# sns_Hist(data=<DF>,
#         x=<横軸>,
#         hue=<基準のcolumn>,
#         figsize=(<横大きさ,縦大きさ>),
#         step=<区切り>)
# ```

# %%
sns_Hist(df, x="bmi", hue="health_condition", step=1)

# %% [markdown]
# # KDEプロット(滑らかなヒストグラム)
#
# ```py
#
# sns_kde(data=<DF>,
#         x=<横軸>,
#         hue=<基準のcolumn>,
#         fill=<True>,                    #塗りつぶすかどうか
#         common_norm=<False>,　　　　　　 #よくわからん
#         figsize=(<横大きさ,縦大きさ>),
#         step=<区切り>)
#
# ```

# %%
sns_kde(df, x='calorie_expenditure',hue='health_condition',
        step=200,
        figsize=(10,5)
       )
